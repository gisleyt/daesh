# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys, os, re, json, codecs
from glob import glob
from operator import itemgetter

import nltk

from wordcloud import WordCloud

# %%
sys.path.append(os.path.join(os.getcwd(), '..', 'lib'))

# %%
from daesh_analysis.lexical_clouds import word_counts
from daesh_analysis.data import data_fns, filter_word

# %%
data_path = '/Users/stinky/Dropbox/daesh/Black Flag'

# %%
wcount = word_counts(data_fns(data_path))

# %%
cloud = WordCloud(background_color="white", width=800, height=400)
cloud.generate_from_frequencies(sorted(wcount.items(), key=itemgetter(1), reverse=True))

# %%
plt.imshow(cloud)
